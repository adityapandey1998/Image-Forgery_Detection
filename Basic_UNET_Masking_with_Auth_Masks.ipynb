# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd  /content/drive/'My Drive'/'CV Project'/
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/CV Project
# BasicCNNwithBatchNorm_Detection    ELA_extracted_X.npy	tmp_img.jpg
# CASIA2.0_revised		   ELA_extracted_y.npy	tp_X.npy
# CASIA2_feature_DCT_LBP.csv	   Masking_Basic.h5	tp_Y.npy
# CASIA2_feature_DCT_LBP_labels.csv  ResNetCNN_Detection

# %%
import os
import numpy as np
import cv2
import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image, ImageChops, ImageEnhance
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.utils.np_utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau, ModelCheckpoint

from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
def get_ela(dir, filename):
    path = os.path.join(dir, filename)
    temp_img = 'tmp_img_bw.jpg'

    image = Image.open(path)
    filtered_image = image.convert('RGB').filter(ImageFilter.BoxBlur(0.5))
    filtered_image.save(temp_img, 'JPEG', quality = 90)
    
    temp_image = Image.open(temp_img)
    
    ela_image = ImageChops.difference(filtered_image, temp_image)
    
    extremas = ela_image.getextrema()
    max_ext = max([x[1] for x in extremas])
    if max_ext == 0:
        scale = 255.0
    else:
        scale = 255.0 / max_ext
    
    ela_image = ImageEnhance.Brightness(ela_image)
    ela_image = ela_image.enhance(scale)

    result = np.array(ela_image.resize((128,128))).flatten()/255

    return result

# %%
au_path = "CASIA2.0_revised/Au"
au_mask_path = "CASIA2.0_revised/Au_mask"

tp_path = "CASIA2.0_revised/Tp"
tp_mask_path = "CASIA2.0_revised/Tp_mask"

img_height = 128
img_width = 128

tp_ids = os.listdir(tp_path)
X = np.zeros((len(tp_ids), img_height, img_width, 3), dtype=np.float32)
X_ELA = np.zeros((len(tp_ids), img_height, img_width, 3), dtype=np.float32)
y = np.zeros((len(tp_ids), img_height, img_width, 1), dtype=np.float32)

for i, file_name in tqdm.tqdm_notebook(enumerate(tp_ids), total=len(tp_ids)):
    img_path = tp_path + "/" + file_name
    image = load_img(img_path)
    img_array = resize(img_to_array(image), (img_height, img_width, 3), mode = 'constant', preserve_range=True)
    file_name, ext = os.path.splitext(file_name)

    gt_img_path = tp_mask_path + "/" + file_name + "_gt" + '.png'
    gt_image = load_img(gt_img_path, color_mode = "grayscale")
    img_mask_array = resize(img_to_array(gt_image), (img_height, img_width, 1), mode = 'constant', preserve_range=True)

    X[i] = img_array.squeeze() / 255
    X_ELA[i] = get_image_with_ela(tp_path, file_name)
    y[i] = img_mask_array / 255

print(X.shape)
print(X_ELA.shape)
print(y.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/5123 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   0%|          | 0/7492 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-614e1e85d9d2> in <module>()
#      39   img_array = resize(img, (img_height, img_width, 1), mode = 'constant', preserve_range=True)
#      40   name, ext = os.path.splitext(name)
# ---> 41   img_mask = img_to_array(load_img(au_mask_path + "/" + name + "_gt" + '.jpg', color_mode = "grayscale"))
#      42   img_mask_array = resize(img_mask, (img_height, img_width, 1), mode = 'constant', preserve_range=True)
#      43   X2[n, ..., 0] = img_array.squeeze() / 255
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     312   """
#     313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 314                         target_size=target_size, interpolation=interpolation)
#     315
#     316
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: 'CASIA2.0_revised/Au_mask/Au_pla_10126_gt.jpg'

# %%
for n, name in tqdm.tqdm_notebook(enumerate(ids), total=len(ids)):
  try:
    img_path = au_path + "/" + name
    img = img_to_array(load_img(img_path, color_mode = "grayscale"))
    img_array = resize(img, (img_height, img_width, 1), mode = 'constant', preserve_range=True)
    name, ext = os.path.splitext(name)
    img_mask = img_to_array(load_img(au_mask_path + "/" + name + "_gt" + ext, color_mode = "grayscale"))
    img_mask_array = resize(img_mask, (img_height, img_width, 1), mode = 'constant', preserve_range=True)
    X2[n, ..., 0] = img_array.squeeze() / 255
    y2[n] = img_mask_array / 255
  except:
    continue

X = np.vstack([X, X2])
y = np.vstack([y, y2])
print(X.shape)
print(y.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
#   0%|          | 0/7492 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 2. Skipping tag 41487
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 41988
#   " Skipping tag %s" % (size, len(data), tag)
# (12615, 128, 128, 1)
# (12615, 128, 128, 1)

# %%
with open('tp_X_all.npy', 'wb') as f:
    np.save(f, X)
with open('tp_Y_all.npy', 'wb') as f:
    np.save(f, y)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.15, random_state=2020)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, BatchNormalization, Activation, Dense, Dropout, UpSampling2D
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
def MyConv(num_filters, num_kernel_size=3):
  conv = Conv2D(
      filters=num_filters,
      kernel_size=num_kernel_size,
      activation='relu',
      kernel_initializer="he_normal",
      padding="same"
  )
  return conv

input_size = (128, 128, 1)
inputs = Input(input_size)
conv1 = MyConv(64, 3)(inputs)
conv1 = MyConv(64, 3)(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = MyConv(128, 3)(pool1)
conv2 = MyConv(128, 3)(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = MyConv(256, 3)(pool2)
conv3 = MyConv(256, 3)(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = MyConv(512, 3)(pool3)
conv4 = MyConv(512, 3)(conv4)
drop4 = Dropout(0.5)(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

conv5 = MyConv(1024, 3)(pool4)
conv5 = MyConv(1024, 3)(conv5)
drop5 = Dropout(0.5)(conv5)

up6 = MyConv(512, 2)(UpSampling2D(size = (2,2))(drop5))
merge6 = concatenate([drop4,up6], axis = 3)
conv6 = MyConv(512, 3)(merge6)
conv6 = MyConv(512, 3)(conv6)

up7 = MyConv(256, 2)(UpSampling2D(size = (2,2))(conv6))
merge7 = concatenate([conv3,up7], axis = 3)
conv7 = MyConv(256, 3)(merge7)
conv7 = MyConv(256, 3)(conv7)

up8 = MyConv(128, 2)(UpSampling2D(size = (2,2))(conv7))
merge8 = concatenate([conv2,up8], axis = 3)
conv8 = MyConv(128, 3)(merge8)
conv8 = MyConv(128, 3)(conv8)

up9 = MyConv(64, 2)(UpSampling2D(size = (2,2))(conv8))
merge9 = concatenate([conv1,up9], axis = 3)
conv9 = MyConv(64, 3)(merge9)
conv9 = MyConv(64, 3)(conv9)
conv9 = MyConv(2, 3)(conv9)
conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

model = Model(inputs = inputs, outputs = conv10)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler

model_checkpoint = ModelCheckpoint('Masking_Basic_All.h5', verbose=1, save_best_only=True, save_weights_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=2, mode='min')
early_stopping = EarlyStopping(patience=10, verbose=1)

# %%
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  640         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 64)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 128)  147584      ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 512)  2359808     ['conv2d_6[0][0]']
#
#  dropout (Dropout)              (None, 16, 16, 512)  0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)   0           ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 1024)   4719616     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 1024)   9438208     ['conv2d_8[0][0]']
#
#  dropout_1 (Dropout)            (None, 8, 8, 1024)   0           ['conv2d_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 1024  0           ['dropout_1[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 512)  2097664     ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 1024  0           ['dropout[0][0]',
#                                 )                                 'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 512)  4719104     ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 512)  2359808     ['conv2d_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 512)  0          ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  524544      ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 256)  590080      ['conv2d_14[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 256)  0          ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 128)  131200      ['up_sampling2d_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_2[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 128)  147584      ['conv2d_17[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 12  0          ['conv2d_18[0][0]']
#                                 8)
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 64  32832       ['up_sampling2d_3[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_1[0][0]',
#                                 8)                                'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 64  36928       ['conv2d_20[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 2)  1154        ['conv2d_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 1)  3           ['conv2d_22[0][0]']
#
# ==================================================================================================
# Total params: 31,031,685
# Trainable params: 31,031,685
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
data_gen_args = dict(horizontal_flip=True,
                     vertical_flip=True)
image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)

batch_size = 32
epochs = 50

image_generator = image_datagen.flow(X_train, batch_size=batch_size, shuffle=True)
mask_generator = mask_datagen.flow(y_train, batch_size=batch_size, shuffle=True)

train_generator = zip(image_generator, mask_generator)

results = model.fit_generator(train_generator, steps_per_epoch=(len(X_train) // batch_size), epochs=epochs, callbacks=[model_checkpoint, early_stopping],
                              validation_data=(X_valid, y_valid))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   app.launch_new_instance()
# Epoch 1/50
# 335/335 [==============================] - ETA: 0s - loss: 43.0082 - accuracy: 0.9587
# Epoch 00001: val_loss improved from inf to 0.17425, saving model to Masking_Basic_All.h5
# 335/335 [==============================] - 110s 280ms/step - loss: 43.0082 - accuracy: 0.9587 - val_loss: 0.1742 - val_accuracy: 0.9544
# Epoch 2/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1584 - accuracy: 0.9586
# Epoch 00002: val_loss improved from 0.17425 to 0.16783, saving model to Masking_Basic_All.h5
# 335/335 [==============================] - 93s 277ms/step - loss: 0.1584 - accuracy: 0.9586 - val_loss: 0.1678 - val_accuracy: 0.9544
# Epoch 3/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9587
# Epoch 00003: val_loss did not improve from 0.16783
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1559 - accuracy: 0.9587 - val_loss: 0.1706 - val_accuracy: 0.9544
# Epoch 4/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1562 - accuracy: 0.9586
# Epoch 00004: val_loss did not improve from 0.16783
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1562 - accuracy: 0.9586 - val_loss: 0.1840 - val_accuracy: 0.9544
# Epoch 5/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9587
# Epoch 00005: val_loss did not improve from 0.16783
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1561 - accuracy: 0.9587 - val_loss: 0.1698 - val_accuracy: 0.9544
# Epoch 6/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1556 - accuracy: 0.9586
# Epoch 00006: val_loss improved from 0.16783 to 0.16651, saving model to Masking_Basic_All.h5
# 335/335 [==============================] - 93s 277ms/step - loss: 0.1556 - accuracy: 0.9586 - val_loss: 0.1665 - val_accuracy: 0.9544
# Epoch 7/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1557 - accuracy: 0.9586
# Epoch 00007: val_loss did not improve from 0.16651
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1557 - accuracy: 0.9586 - val_loss: 0.1673 - val_accuracy: 0.9544
# Epoch 8/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1557 - accuracy: 0.9586
# Epoch 00008: val_loss did not improve from 0.16651
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1557 - accuracy: 0.9586 - val_loss: 0.1671 - val_accuracy: 0.9544
# Epoch 9/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9589
# Epoch 00009: val_loss did not improve from 0.16651
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1543 - accuracy: 0.9589 - val_loss: 0.1694 - val_accuracy: 0.9544
# Epoch 10/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.9583
# Epoch 00010: val_loss did not improve from 0.16651
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1565 - accuracy: 0.9583 - val_loss: 0.1674 - val_accuracy: 0.9544
# Epoch 11/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9589
# Epoch 00011: val_loss did not improve from 0.16651
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1541 - accuracy: 0.9589 - val_loss: 0.1674 - val_accuracy: 0.9544
# Epoch 12/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9586
# Epoch 00012: val_loss did not improve from 0.16651
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1551 - accuracy: 0.9586 - val_loss: 0.1666 - val_accuracy: 0.9544
# Epoch 13/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 0.9589
# Epoch 00013: val_loss did not improve from 0.16651
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1539 - accuracy: 0.9589 - val_loss: 0.1710 - val_accuracy: 0.9544
# Epoch 14/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9582
# Epoch 00014: val_loss did not improve from 0.16651
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1564 - accuracy: 0.9582 - val_loss: 0.1677 - val_accuracy: 0.9544
# Epoch 15/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1529 - accuracy: 0.9592
# Epoch 00015: val_loss did not improve from 0.16651
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1529 - accuracy: 0.9592 - val_loss: 0.1689 - val_accuracy: 0.9544
# Epoch 16/50
# 335/335 [==============================] - ETA: 0s - loss: 0.1557 - accuracy: 0.9583
# Epoch 00016: val_loss did not improve from 0.16651
# 335/335 [==============================] - 91s 273ms/step - loss: 0.1557 - accuracy: 0.9583 - val_loss: 0.1670 - val_accuracy: 0.9544
# Epoch 00016: early stopping

# %%
plt.figure(figsize=(8, 8))
plt.title("Training Curve")
plt.plot(results.history["loss"][1:], label="Train Loss")
plt.plot(results.history["val_loss"][1:], label="Validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
P_train = model.predict(X_train, verbose=1)
P_val = model.predict(X_valid, verbose=1)
# Out:
# 336/336 [==============================] - 25s 75ms/step
# 60/60 [==============================] - 4s 75ms/step

# %%
id = 1
plt.imshow(X[id, ..., 0])
plt.show()
plt.imshow(y[id].squeeze())
plt.show()
plt.imshow(P_train[id].squeeze(), vmin=0, vmax=1)
plt.contour(y[id].squeeze(), colors='k', levels=[0.2])
plt.show()
plt.imshow(P_train_t[id].squeeze(), vmin=0, vmax=1)
plt.contour(y[id].squeeze(), colors='k', levels=[0.2])
plt.show()

# %%
id = 9
# fig, ax = plt.subplots(1, 4, figsize=(20, 10))
plt.imshow(X[id, ..., 0])
plt.show()
plt.imshow(y[id].squeeze())
plt.show()
plt.imshow(P_train[id].squeeze(), vmin=0, vmax=1)
# plt.imshow(im_bw, vmin=0, vmax=1)
plt.contour(y[id].squeeze(), colors='k', levels=[0.2])
plt.show()
plt.imshow(P_train_t[id].squeeze(), vmin=0, vmax=1)
plt.contour(y[id].squeeze(), colors='k', levels=[0.2])
plt.show()
